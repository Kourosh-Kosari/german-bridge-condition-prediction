# %% [markdown]
# # 23 — GitHub Web Deployment Package
#
# Deployment specification for the final GitHub Pages repository structure.

# %%
from pathlib import Path

PROJECT_ROOT = Path(r"C:\Datenanalyse\final Project")
OUTPUT_ROOT = PROJECT_ROOT / "Output_PlanA-B"
DEPLOY_ROOT = OUTPUT_ROOT / "23_GitHub_Web_Deployment_Package" / "GitHub_Deployment"

SOURCE_PLAN_A = OUTPUT_ROOT / "17_Plan_A_Germany_Web_Map" / "plan_a_germany_bridge_map.html"
SOURCE_PLAN_B = OUTPUT_ROOT / "21_Plan_B_Final_Interactive_Interface" / "plan_b_final_interface.html"

print("Source Plan A:", SOURCE_PLAN_A)
print("Source Plan B:", SOURCE_PLAN_B)
print("Deployment root:", DEPLOY_ROOT)
print("Notebook 23 purpose: build the static GitHub Pages package from the completed Plan A and Plan B outputs.")
